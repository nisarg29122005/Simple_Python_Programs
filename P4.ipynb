# %% [markdown]
# <a href="https://colab.research.google.com/github/nisarg29122005/Simple_Python_Programs/blob/main/P4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 0
std_dev = 1
size = 100
data = np.random.normal(mean, std_dev, size)

print("Dataset:")
print(", ".join([f"{x:.2f}" for x in data]))

plt.hist(data, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black')

x = np.linspace(min(data), max(data), 1000)
y = (1 / (std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)
plt.plot(x, y, color='red', linewidth=2)

plt.title("Histogram of Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Density")

plt.show()
# Out:
# Dataset:
# -0.09, -0.92, 0.47, -1.15, -0.10, 1.10, -0.17, 0.38, 1.62, -0.30, 1.21, 0.87, -1.51, -2.72, -1.22, -0.14, -0.20, 2.49, 0.58, 0.87, -0.38, 0.87, -1.25, -1.66, 1.77, 1.03, -0.57, -0.26, 1.50, 0.84, 1.30, 0.06, 0.35, -1.54, 1.22, -0.41, -0.68, 1.42, 1.04, 0.62, 0.93, 0.30, -1.96, 1.33, 0.90, -2.40, 1.15, 0.49, 0.39, 0.29, -1.53, 0.70, 1.54, 0.47, 0.96, 0.25, -0.62, 1.73, 2.01, -0.42, -0.63, 0.04, -0.01, -0.32, -0.64, -0.38, -0.57, 0.19, 0.43, -2.02, -0.15, -2.01, 0.76, -0.04, 0.15, 1.98, -0.96, -1.06, -1.44, 1.13, 0.46, 1.40, -0.89, -1.35, -0.72, 0.30, 0.07, -1.26, 0.33, -1.22, -1.33, 0.51, -0.71, -0.77, 0.43, 1.19, -0.94, -0.73, 1.48, -0.40
